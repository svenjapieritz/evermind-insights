# %%
from pyathena import connect
import pandas as pd
import os
import re 

#Assume role before!
conn = connect(aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
              aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'),
              aws_session_token=os.getenv('AWS_SESSION_TOKEN'),
              s3_staging_dir='s3://aws-athena-query-results-878189897945-eu-west-1/',
              region_name='eu-west-1')

query = "SELECT * FROM alpha_health_evermind.events"
df = pd.read_sql(query, conn)
df
# Out:
# /Users/yc00123/.virtualenvs/py3.6.8-data-access/lib/python3.6/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                               createdat deploymentenv  \
# 0      2019-11-16T08:04:30.729961+00:00          prod
# 1      2019-11-16T08:04:31.119303+00:00          prod
# 2      2019-11-16T08:04:31.122276+00:00          prod
# 3      2019-11-16T08:04:31.124669+00:00          prod
# 4      2019-11-16T08:06:00.430315+00:00          prod
# ...                                 ...           ...
# 81611  2019-11-27T17:47:58.584187+01:00          prod
# 81612  2019-11-27T00:28:47.444146+00:00          prod
# 81613  2019-11-27T00:28:59.191603+00:00          prod
# 81614  2019-11-27T09:10:28.714299+00:00          prod
# 81615  2019-11-27T09:24:15.778234+00:00          prod
#
#                                                   device        event  \
# 0      {id=A01CFEC1-B0EA-4866-8739-940D6A507080, mode...     app_open
# 1      {id=A01CFEC1-B0EA-4866-8739-940D6A507080, mode...   app_resume
# 2      {id=A01CFEC1-B0EA-4866-8739-940D6A507080, mode...  screen_view
# 3      {id=A01CFEC1-B0EA-4866-8739-940D6A507080, mode...  screen_view
# 4      {id=A01CFEC1-B0EA-4866-8739-940D6A507080, mode...          tap
# ...                                                  ...          ...
# 81611  {id=4A34E0CE-3ECC-44C0-8739-0E079A259A10, mode...   app_resume
# 81612  {id=e422b492c35609ef, model=SM-G970F, platform...   app_resume
# 81613  {id=e422b492c35609ef, model=SM-G970F, platform...    app_pause
# 81614  {id=6A6006D4-682A-4352-BD83-D116007097E4, mode...    app_pause
# 81615  {id=a9a1e3f5498c6aac, model=SM-G950F, platform...    app_pause
#
#                                                  product  \
# 0      {id=com.wingmanalpha.app.evermind, name=Evermi...
# 1      {id=com.wingmanalpha.app.evermind, name=Evermi...
# 2      {id=com.wingmanalpha.app.evermind, name=Evermi...
# 3      {id=com.wingmanalpha.app.evermind, name=Evermi...
# 4      {id=com.wingmanalpha.app.evermind, name=Evermi...
# ...                                                  ...
# 81611  {id=com.wingmanalpha.app.evermind, name=Evermi...
# 81612  {id=com.wingmanalpha.app.evermind, name=Evermi...
# 81613  {id=com.wingmanalpha.app.evermind, name=Evermi...
# 81614  {id=com.wingmanalpha.app.evermind, name=Evermi...
# 81615  {id=com.wingmanalpha.app.evermind, name=Evermi...
#
#                                               schema     source   type  \
# 0      /schemas/events/analytics-device-event/0.json  analytics  track
# 1      /schemas/events/analytics-device-event/0.json  analytics  track
# 2      /schemas/events/analytics-device-event/0.json  analytics  track
# 3      /schemas/events/analytics-device-event/0.json  analytics  track
# 4      /schemas/events/analytics-device-event/0.json  analytics  track
# ...                                              ...        ...    ...
# 81611  /schemas/events/analytics-device-event/0.json  analytics  track
# 81612  /schemas/events/analytics-device-event/0.json  analytics  track
# 81613  /schemas/events/analytics-device-event/0.json  analytics  track
# 81614  /schemas/events/analytics-device-event/0.json  analytics  track
# 81615  /schemas/events/analytics-device-event/0.json  analytics  track
#
#                    unique_name                                       user  \
# 0           app_open.null.null  {id=A01CFEC1-B0EA-4866-8739-940D6A507080}
# 1         app_resume.null.null  {id=A01CFEC1-B0EA-4866-8739-940D6A507080}
# 2      screen_view.splash.null  {id=A01CFEC1-B0EA-4866-8739-940D6A507080}
# 3      screen_view.splash.null  {id=A01CFEC1-B0EA-4866-8739-940D6A507080}
# 4           tap.splash.sign-up  {id=A01CFEC1-B0EA-4866-8739-940D6A507080}
# ...                        ...                                        ...
# 81611     app_resume.home.null  {id=a03308ca-fbaf-4265-8257-b6ecf7ec4d40}
# 81612     app_resume.home.null  {id=fc9c6a6e-d60a-4d5c-a6bf-0fc9f644b91b}
# 81613      app_pause.home.null  {id=fc9c6a6e-d60a-4d5c-a6bf-0fc9f644b91b}
# 81614  app_pause.activity.null  {id=b313ea43-b62a-4405-b32b-c809d08529a1}
# 81615  app_pause.activity.null  {id=6a252400-4aaf-46ab-aeb7-6788d4bb140f}
#
#        ...      view                                               data  \
# 0      ...      None                                               None
# 1      ...      None                                               None
# 2      ...    splash                                               None
# 3      ...    splash  {view=splash, question=null, answers=null, sco...
# 4      ...    splash                                               None
# ...    ...       ...                                                ...
# 81611  ...      home                                               None
# 81612  ...      home                                               None
# 81613  ...      home                                               None
# 81614  ...  activity                                               None
# 81615  ...  activity                                               None
#
#        element error level message stacktrace  year month day
# 0         None  None  None    None       None  2019    11  16
# 1         None  None  None    None       None  2019    11  16
# 2         None  None  None    None       None  2019    11  16
# 3         None  None  None    None       None  2019    11  16
# 4      sign-up  None  None    None       None  2019    11  16
# ...        ...   ...   ...     ...        ...   ...   ...  ..
# 81611     None  None  None    None       None  2019    11  27
# 81612     None  None  None    None       None  2019    11  27
# 81613     None  None  None    None       None  2019    11  27
# 81614     None  None  None    None       None  2019    11  27
# 81615     None  None  None    None       None  2019    11  27
#
# [81616 rows x 21 columns]

# %%
df['event'].unique()
# Out:
# array(['app_open', 'app_resume', 'screen_view', 'tap', 'app_pause', None,
#        'impression', 'activity_results', 'media_pause', 'select_date',
#        'assessment', 'media_finish', 'media_play',
#        'app_resume_from_notification', 'app_open_from_notification',
#        'media_restart'], dtype=object)

# %% [markdown]
# ## Setting the timestamp as index

# %%
df['createdat']=pd.to_datetime(df['createdat'], utc=True)
df.set_index('createdat', inplace=True)
df.index = df.index.floor('1H')
df['week_start'] = df.index.to_period('W').start_time
# Out:
# /Users/yc00123/.virtualenvs/py3.6.8-data-access/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1102: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %% [markdown]
# ## Function to calculate the score of the PSS

# %%
df.columns
# Out:
# Index(['deploymentenv', 'device', 'event', 'product', 'schema', 'source',
#        'type', 'unique_name', 'user', 'userid', 'view', 'data', 'element',
#        'error', 'level', 'message', 'stacktrace', 'year', 'month', 'day',
#        'week_start'],
#       dtype='object')

# %%
df[df['event']=='assessment']['data'].iloc[0].split()
# Out:
# ['{view=null,',
#  'question=null,',
#  'answers=[2,',
#  '2,',
#  '2,',
#  '1,',
#  '2,',
#  '3,',
#  '3,',
#  '2,',
#  '1,',
#  '2],',
#  'score=20,',
#  'programme-id=null,',
#  'programme-title=null,',
#  'activity-id=null,',
#  'activity-title=null,',
#  'slide=null,',
#  'page=null,',
#  'input-id=null,',
#  'feedback=null,',
#  'audio-id=null,',
#  'duration=null,',
#  'position=null,',
#  'level=null,',
#  'module-id=null,',
#  'module-title=null,',
#  'action=null,',
#  'labels=null,',
#  'labels-selected=null,',
#  'records-done=null,',
#  'questionsanswered=null,',
#  'notification=null,',
#  'date=null,',
#  'programme-state=null,',
#  'step=null,',
#  'suggested=null,',
#  'programme-step=null,',
#  'answer-id=null,',
#  'aswer-value=null,',
#  'answer-ids=null,',
#  'answer-values=null,',
#  'example=null,',
#  'numofdaysago=null,',
#  'iscompleted=null,',
#  'group=null}']

# %%
assessment20 = df[(df['event']=='assessment')&(df.index.year == 2020)]['data']

# %%
assessment19 = df[(df['event']=='assessment')&(df.index.year == 2019)]['data']

# %%
def getScore(s):
    n = re.search('score=(\d+)', s)
    score = int(n.group(1))
    return score

# %%
def getAnswers(s):
    m = re.search(r"\[(.*)\]", s).group()
    a = re.sub('\D',' ',m)
    answers = a.split()
    return answers

# %%
scores19 = assessment19.apply(getScore)

# %%
scores20 = assessment20.apply(getScore)

# %%
assessment19.apply(getAnswers)
# Out:
# createdat
# 2019-12-30 13:00:00+00:00    [2, 2, 2, 1, 2, 3, 3, 2, 1, 2]
# 2019-12-28 22:00:00+00:00    [2, 2, 2, 2, 1, 1, 2, 1, 1, 2]
# 2019-12-20 08:00:00+00:00    [2, 2, 2, 2, 2, 0, 2, 2, 3, 1]
# 2019-12-19 06:00:00+00:00    [1, 2, 3, 2, 2, 3, 3, 2, 1, 2]
# 2019-11-15 13:00:00+00:00    [2, 1, 2, 3, 3, 2, 2, 2, 2, 2]
#                                           ...
# 2019-11-27 21:00:00+00:00    [1, 3, 4, 3, 2, 3, 3, 4, 3, 3]
# 2019-11-29 08:00:00+00:00    [0, 1, 3, 0, 1, 3, 2, 3, 2, 1]
# 2019-11-27 10:00:00+00:00    [2, 0, 2, 1, 2, 2, 1, 1, 2, 1]
# 2019-11-27 17:00:00+00:00    [1, 2, 2, 2, 3, 2, 2, 2, 2, 1]
# 2019-11-27 12:00:00+00:00    [1, 2, 1, 1, 2, 1, 1, 1, 1, 1]
# Name: data, Length: 74, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
figure = sns.distplot(scores19)
figure.set(xlabel = 'Perceived Stress Score')
# Out:
# [Text(0.5, 0, 'Perceived Stress Score')]

# %%
figure = sns.distplot(scores20)
figure.set(xlabel = 'Perceived Stress Score')
# Out:
# [Text(0.5, 0, 'Perceived Stress Score')]

# %% [markdown]
# ## Scores over time for individual users

# %%
df.userid.unique()
# Out:
# array(['A01CFEC1-B0EA-4866-8739-940D6A507080', 'c57c753487db7965',
#        '8041B5EB-7984-4CB9-9A58-4EFDC84F265D',
#        '46dc9b12-42c4-4ba7-8c1c-9d1404e0903a', '812c2e41c64d3b51',
#        '64bfce03-6337-4208-a1ac-d92269faf24b', '70a94f23afa7b234', '',
#        'a03308ca-fbaf-4265-8257-b6ecf7ec4d40',
#        '4A34E0CE-3ECC-44C0-8739-0E079A259A10',
#        '902FEAEE-E290-4424-BA44-04F70A77DC9D',
#        'E2D7D48D-08C5-4228-B9D6-7A9830FCBB48',
#        '38512D7C-8F81-4AD3-B7B9-46963C0635FC', 'c65dcc742f28bd0f',
#        'fc9c6a6e-d60a-4d5c-a6bf-0fc9f644b91b', 'e422b492c35609ef',
#        '6a252400-4aaf-46ab-aeb7-6788d4bb140f', 'a9a1e3f5498c6aac',
#        '34224694-17A3-4806-ACBF-AE598912E003',
#        '9130c977-71cd-4b6e-a8e0-6d269e2e0022',
#        'E9ACE06B-2605-4FAA-A6F0-C016743328FC',
#        '8F8A3E40-C1AF-4D0C-8456-72153A451747', 'c481f6cb3a459905',
#        '422656486535f884', 'ba7c625f-8845-492b-ad84-0e396fd26d5a',
#        '6359B6AD-DBA0-4DCF-8166-BB8ABACDC814',
#        '84AC2979-EF1E-4C68-ACD1-0AEB5AEF7200',
#        'fde78b86-e4f9-4546-853b-6882c8b4f085',
#        'dc744407-3f77-4398-95a1-101c1e46eb7b',
#        '9F69CC76-F402-476A-BB44-A84292010E46',
#        '7ccaf221-811f-4f97-be46-e5e01454e500',
#        'E0EF0138-AEB8-4F06-B0B4-7CE655B0DC52',
#        '2397e1e3-e7b4-459a-82c6-c8a69cdc7031',
#        'E0861AD8-B39B-40BE-8C88-543DD2E5878F',
#        'bbe616de-e329-4acb-988f-b8180a109d88',
#        '5730a6dc-4b30-48dc-b334-e8228a243c76',
#        'B8F2BB36-BDBB-4610-8B45-0717E7505C72',
#        'A586B11B-09C7-4212-A0B2-68ABA386375B',
#        '63947F2F-168F-48CB-A5EB-71A40A0FAC05', '6f10800d4bc7a5f9',
#        'b9226e9d-f839-46e9-8e2b-e27fa42736aa',
#        '1843b45d-4580-4969-bf0a-318a3bce4b32', '546b160edc74ce94',
#        '696e2ae2-c892-4f43-aa0c-8336bd353d45', '9c9a096268a053b1',
#        '0E596382-CBC5-4336-8A54-B10C04483D30',
#        '60CB3387-2B79-4949-AC18-964E8ED56D58',
#        'f8c2b15d-b803-435d-adf9-42ee09da9165',
#        '23ECCD1E-081C-465F-A868-2876DDA2C99E',
#        'F6681229-293C-4D2A-B8FA-A08CC0DEC710',
#        '54d3e190-ee81-4801-8b35-b484123f0080', '2666fe4da6917afa',
#        '1C3127FC-DFE6-4E44-9D5D-823E234078ED',
#        '6e30e339-2e5d-496b-9c33-7ceaad26c66e',
#        'd4db310c-c9c6-4d91-a116-9e004fb670be',
#        'aca95b64-daaf-494c-8178-d9acf60573d2',
#        '57d18538-07e7-4067-abcc-806f3d20654b',
#        '5BFB4CBA-F9F1-402D-AA8E-BDB788E1C264',
#        '3ADA6F03-837F-499F-8A1E-B2FE66BD9B3D',
#        '10568754-EDC4-482B-BADB-8D04F3AF1D66',
#        '42F56FE6-1C07-42D7-861D-108BFFDAB807',
#        '798790c2-c8b1-468d-b061-5ede38be36bc',
#        'db49e66f-16c1-4940-922e-0f7504716642',
#        '7562edab-708a-44b7-a78d-43d04c0579ea',
#        '967ebdad-0c6e-40f7-8363-2fedf955c8cb',
#        '418cdc61-3e99-464d-8098-8dc0e48ac70d',
#        '161B330F-59D7-4A7C-85DB-325721119AD5',
#        'c7d94497-16a6-4983-bbd8-d49e5939c3b4',
#        '2777CD3D-7AA8-4461-BB54-DC7338E51EC1',
#        '8e8e3863-041e-497a-8544-107efdb3d5cb',
#        '1ACC78BD-B3AA-468F-ADA5-93D0D2F49023',
#        '512f8c5d-fd9b-41bc-a25b-f2f714316405',
#        'f5ff9aca-0969-432b-994f-e3ef1649ad04',
#        '25dc8ef7-88f9-4cb8-809d-5eaa8e9557ca',
#        '13e85eda-d37a-4ee1-b6e9-132136e184a7',
#        '02de1825-88b8-4bd7-a473-49620e9a7e60',
#        '2fd9db56-0177-4033-9ced-cb323a4cac68',
#        '8510bafc-eb6d-42bb-a378-17077a0eaf9d',
#        '2e348405-1f0e-45ee-8ab4-504ed346c305',
#        'c144e79d-43ec-4574-b878-43a1b52d383d',
#        'a6a9b40e-58a7-41ad-9c0b-9a225b7aa589',
#        '34ee15cb-9ba7-46a8-9370-495467e48381',
#        'df17bd69-9d0f-4469-bbc5-22f43ddbfc03',
#        'B1200A69-9349-4BBA-B1FE-6EE602819C19',
#        '4FF4A0D8-3684-4502-844D-9810D5230982',
#        '42735b08-ef07-42c6-aa3c-34044f8635ac',
#        'f14deb82-408e-4c19-9628-c1599867f62f',
#        'f7b04a7c-d5dd-4472-bde0-af491d886cf3',
#        '36980a9e-ddfe-4bd4-953d-9de4d700a824',
#        '07B2B14E-7728-4DB8-8BEC-EC03B0B013DB',
#        'e2b25de5-444e-4f7c-82f2-a2207181a93a',
#        '8754B240-FC52-43ED-AA5B-90F4FC3861AF', '41b2ab47f20c0028',
#        '061f2a442a4fcf66', 'da1eacad1374f44e', 'cff4db93305c89de',
#        '2251df37935a0656', '24AC0515-1DDB-409B-A8B0-64F16A0A816A',
#        'ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6',
#        '18800e51-91be-403e-8c43-1743dee944c3',
#        '4e672aa1-7d57-48cb-8765-2e703c7944e6',
#        '37BDED79-0AD7-4270-9459-85183B1CC53A',
#        'fd0bc52e-d1a4-405a-bd01-300a3d430209', 'ca68e1cd0f40585f',
#        'B95D3D48-9F29-4699-9BBD-162D89CDC722',
#        '2be3847e-32d4-469e-a5a2-66c3840a4717',
#        '90955803-F632-4ECB-87EF-4F7960F5740E', '89d48011430dab6b',
#        '127f8f12-4868-4991-b1f4-d951e8997638',
#        '6dce0158-0d78-43a3-afdf-c6a5801859c7',
#        '485e779e-6d30-4184-8cb3-59445975e2a5',
#        '8cef69d0-ed99-4bc2-b91e-ad18583a3754',
#        '91bcf5c1-ceaa-42de-abdc-c5632115f7a7',
#        '4c0831d9-6ad4-4cef-be58-3a510a6b602c',
#        '89406779-94FE-4E47-B6A0-08C60C16584B',
#        '062D2763-2D7B-487B-83F9-EE4E9E1A18FA',
#        'b3540d53-9891-4b14-b430-659d0a25ad5e',
#        '04f287a8-c498-4655-896b-0231185e16a8',
#        '41e1dcca-20c7-4027-b36b-4386740a535b',
#        'c2c76c5b-4b23-4371-b0dc-f37586b73665',
#        'F66D48B7-019E-46E8-9EAC-6B039E39C3FF', '804092dc0980c958',
#        'fd34dca14dae2587', '1787692d-11e7-443a-9c63-302fb9c7e4c7',
#        '6a757a26-10f3-4dd8-a6ca-a2e9c7318128',
#        '2fe1a68c-620b-4a5e-a1ab-ef13866843ce',
#        '1b97b8c2-c0c2-4a8e-8770-f8fae46a3a3e',
#        '758794A6-BAEC-4247-8499-FE2B018B6523',
#        '00da7219-c1bd-4b67-acc5-fa6da0668d05', 'd2348342b5c7ef36',
#        'B554FD14-6625-4805-9CD5-5ED082C4E18B',
#        '811914dc-1c74-498c-9271-b8c0abb536b5',
#        'E17AB04B-A68F-4C08-B920-075A2FA824D5',
#        '09892EF9-FC34-44DE-88B8-58D627C6636E', 'c4fe084ac590838a',
#        '20F9BD67-64C5-44AB-9EF5-8ED664514D0D',
#        'C1753934-9F85-448C-90D2-FC69F5EFC4DB',
#        '4884D316-2533-4BC0-A5AE-4C4A37405FB4',
#        '169E42E6-06C9-46ED-B45E-21C88B1CADC1',
#        '05A7E3CF-613E-4272-8DAC-FA7B8FA2677E',
#        '0317E9ED-6A5B-4A33-827F-3A73485071E1', 'd428fa268048fa93',
#        'ed66ee43-8077-49ac-a03f-4be17c94eb17', '6347d70b7d291f95',
#        '1CED046F-257E-46FD-92FA-B46095BF33A6', '837a5405f4ca726f',
#        'b313ea43-b62a-4405-b32b-c809d08529a1',
#        '6A6006D4-682A-4352-BD83-D116007097E4',
#        '74da9410-d798-4442-9137-6be07825c023',
#        '9259D142-4EF5-4FCE-B47D-4AB9226312EA', '15b11623e50bf6d4',
#        '2224f1f8a8f4e529', '9c47cf0b47d5c9c5',
#        '8514d65d-b725-4f39-b1fc-5b0a614ff18a',
#        '1ad71f48-c2cd-4261-97da-5ac6d513e8ee',
#        '98f3942d-c356-48c2-946e-02f91726e9b7',
#        '83b49381-564b-4772-a863-1730e70e571d',
#        '58b8ef9c-79a8-453f-bc61-23ecfa013574',
#        'bd477c25-b5e1-4ef5-8f9e-50f9579043d8',
#        '414c053e-a8a3-48fd-99b6-055a4b0cb39a',
#        'e4e586dc-1d64-49d2-823a-b7df2ad935d9',
#        '2566cff2-e8a3-4ee1-a1f9-d4a141b8dc90',
#        '09d6008f-32cd-4cc0-ac2c-5f7d0c5d041f',
#        'cb5cbcae-8af9-4561-a0c9-1ce4908d59d1',
#        '4a5a61c1-7b89-4a98-8c02-b2322afbd821',
#        'ec0dd93f-fa73-4262-af5c-fb508e87b6e1',
#        'c11178dd-cee1-4431-99ef-db8f02d1f6d7',
#        '62ec9abb-9f9c-49c6-8feb-a9485cbbc7ab',
#        '044a1e47-e2aa-4d90-8ad3-00c63096d085', 'e48cdd0765262bbc',
#        '832a9d1a-cfce-4799-9665-df83b0068ee2',
#        '7c2c5111-fe6b-4fa3-8ac2-704156d31ac2',
#        '44c3e3e5-5fdf-438b-b59a-aaba9d73ced6',
#        'd235664b-1334-4f72-8ba7-9b3a735d2f3d',
#        '9768a63d-772a-4c85-b902-d4d2152b6f17',
#        '9156d626-59cb-4a58-919a-b0824cfcd8ed',
#        'd9816d3a-14aa-472b-a7dd-2ffaec421a3e',
#        'e359dc7c-4190-4f23-838d-ae420718645b',
#        '42d1d0c5-53e6-4c3e-b947-9f62ce6b95ab',
#        '3016f096-50d6-4613-ac4e-ebd984abcdaf',
#        '6f467272-a48b-4118-b3f0-a0838b653c17',
#        '327396da-73c8-4cb0-8334-77a2f472b2e0',
#        '98602C5C-3793-4FB6-8C4B-36795624FFE5', '38bd9767f1b6486a',
#        '14c04a584fda0d70', 'dc9578be-0093-4526-8495-ea3550933fb1',
#        'd0c3d07a-bc7f-4f43-b49d-058f1dd20517',
#        '6d7d417e-bff2-4bbd-8703-2dc1d9a33ace',
#        '30e9490b-003b-4c94-9473-1b6229e238c5',
#        'e6a76d13-dce5-47e2-8210-34f7b2b1abb6',
#        'f26b45f7-1b81-4d9c-8e14-b900bea9e2fd',
#        'a30c0386-233f-4cab-805d-4f0de6a4630e',
#        '758277e0-a73b-4e3a-9368-928d61ea407b',
#        '42A5A385-8FDA-4903-9520-02F4684D33C1',
#        '9D3CE609-4DCC-4425-A70F-D1011297B0EF',
#        'cbc76578-b3af-407e-b1b1-656eb08a9c7e',
#        '21218fbe-4ef4-48c4-a6cc-fec0a9705243',
#        'b0acecbf-6aac-4df4-bda6-6b2d5234193d',
#        'c137634b-03c7-439c-b504-6dbe2374c4e9',
#        '6F380742-C788-42F7-9A56-090BF2B76E0F',
#        '6eedcfe1-ab68-4fb3-b858-a1190da5816f',
#        '3376fe04-5281-4c85-b4e6-7e8cd88970cb',
#        '6bf74034-746b-40a9-b32c-ff56dc082683',
#        'A264F912-2BDA-4311-833E-FC4E207DE7C7',
#        'a7bf7453-a776-4e35-ac5d-a766a36b98d2',
#        'e41090ce-d241-45f9-ac28-d8baba77fc91',
#        '0ac87483-0b76-46c6-823d-51280084f7e0',
#        '43CEEA10-0F45-4E67-9BD7-5D88783BBB05',
#        'e62dedad-169c-4d5d-a883-0951d8f3500c',
#        '417ec70a-ec44-4ef4-88d0-a3a03cda5131',
#        '851ad004-0956-482c-b024-db4479b8946b',
#        '340de9e9-9957-4ae6-b6ee-d7fa51959ea4',
#        '6aa95895-5274-4770-ab38-0a1beeef1681',
#        '1a8b8e72-4a68-4cc2-ad11-882143b68619',
#        'c02e93b1-2371-4139-bd4e-372edc53b62d',
#        '01021dae-990a-4713-b087-a4208dde3f3d',
#        'f69d743e-7f09-4a13-bfa6-f37b7a330b46',
#        '2D99E723-AEA0-4FBA-9574-A0E9112785B3',
#        '3d359af5-f066-4ac2-9a9f-d93f3cea0011',
#        '059f7353-1c2d-4a75-a1d5-9a4ca5251794',
#        '56369fa6-0850-4112-a1f6-cb430a0af776',
#        '7E0B0934-DB48-429C-9AC2-3ED58117514C',
#        '8ca7d00e-c062-425a-9b26-2105e874b8d9',
#        '3167EF50-1132-4574-9F8A-E202D3EF16BA',
#        'a08bd409-62ce-4b62-b24c-463c9f1c20ba',
#        'f21a3d0f-c97d-4805-95c0-f588f1b1f04e',
#        'efe7db4f-e32b-48ca-99cc-d341f4cf201e',
#        '3133a51a-1751-4df8-a3bd-1df4f31d0263',
#        'f54a26ca-9476-4514-b46b-fd155c253f39',
#        '7431f66a-4856-4174-8b51-b73b5bf5f88a',
#        'aa55c25e-505d-4e85-b642-65ecb4249b3b',
#        'A8227FB6-6D7A-43F1-BE70-827B74C6D4C7',
#        '5769A367-B76B-4EA7-822B-332D1499F3E5',
#        '2dc654e4-1adc-4125-84a5-078578ecb315',
#        '53801b9e-49b5-4b08-b964-4adfa1f965b2',
#        '264BB644-1957-4A04-9ECF-00A2893766A1',
#        'c15a74f8-debf-4efc-8cbe-618634c05c57',
#        '70241aa9-2dbe-4722-a8f0-d29cac38855e', '3f972c43a988e728',
#        'ed9e1e97-6eee-430e-bfb1-916e8a91354e', 'd621e6004268731e',
#        '47006b43-c4d6-4b13-b836-4a8f91103650',
#        'daee3887-b466-4baf-9f67-666f375d26af',
#        'AC44D941-1CC2-4E13-A624-01957477C7E3',
#        '9b3c9e70-17a9-4245-ba75-c890daa333d4',
#        '33dfe98b-5cdb-4133-a20c-08e02683d117',
#        '3d803fe7-a4c9-4e39-be43-5c7d7d46d117',
#        'fd82739a-393f-4a3e-ada8-4f2355154c77',
#        'FC12B169-0ADF-457E-BF24-7BD17BA01857',
#        '7b1a5a5d-aca3-4709-9880-76b38a57edf3',
#        '29920e58-3a00-4e00-b7f1-94b3522a462e',
#        '46a93fab-1e49-46d9-8faa-c21fb0a78ecd',
#        'd16520f6-ac2f-44fd-94b1-cf7f62eda852',
#        '0b24938d-75ef-438b-a1f4-60e227c44601',
#        '4104a431-13ce-4e9d-abd9-9de4ca8788a8',
#        'c4618b6d-6a80-4ac8-8382-45efb12e698f',
#        'fd6b7f72-4220-4e08-a230-94c6cbe2fe0d',
#        '21bc1db2-4384-4d9d-ba29-fa06b194fc30',
#        '3a7bcedd-a613-4b51-aca0-3208bea934cc',
#        '14b74364-ce50-45ca-8c29-3de397c804a3',
#        '176AA6F1-C2CF-4EEA-8C46-E220C3F268F7',
#        '3C71B67D-8FAC-4F3E-A25F-E47750201BE7',
#        'fa598088-7914-4bee-b615-b4ef529c18d2',
#        '8c1cc8b1-0656-4837-816b-effa50d61338',
#        '4D8AA9FB-EB69-47A1-8230-A0AAA9424767',
#        'F05CABA5-969B-4C04-B81A-2AC54AE23C11',
#        '9c2bd9b2-7cb6-419c-8024-5b872a039f46',
#        '88391e33-7932-4fb4-9a7f-8d51279f5d3e',
#        'cf6b1eea-eb1e-453d-84da-9dfcba375511',
#        '2199482A-8705-49B6-B09D-2FCC728B7BB1',
#        '49256c1f-05ae-4d5e-888f-4395c49c7db1',
#        '9bf79edb-d59c-4100-a162-0fd9a4d3f2a9',
#        '0bb0a670-1f15-42b5-9be5-e0a8cfd9759a',
#        'e3a037bf-4cee-4a31-b82d-20a82f732d3b',
#        'BC032968-78E3-4277-9842-C0D2BD0FF215',
#        '6698006d-ecce-4731-862d-410295f43fe7',
#        '325da042-721e-4733-86e5-cf45fbe01c45',
#        'e8d5e264-1013-408a-a4c9-068b3d79858e',
#        'ca44748a-c8e2-4b2a-8de1-e73c0e9636b3', '4fc9b53f698c0bf4',
#        'A6945F8A-DD8C-49C9-9FCB-2DD773249714',
#        '39b877b7-3146-44ec-b413-20999d75b874',
#        '6529fdf3-9886-41e8-a15f-264332e51ac6',
#        'bf95c98d-4e90-4d13-8df5-286f6622a181',
#        'ba0f4912-ab8d-483c-8a7a-d3cab06cfd3f',
#        '339ae7ff-b5c5-4ebc-9caa-1d247e8e58e0',
#        'e253249b-66c1-4fff-87d1-3adbe827b3fc',
#        '9623721b-49b1-49ba-ae0b-7645c72f1888',
#        '7d6fc309-19d9-4740-96e9-bbbf3184588e',
#        'd7844a2d-8249-408a-ac75-820d308f0c9a',
#        '2c4d55f3-1058-446d-b83b-a1ebc71b6f1e',
#        '0110e85c-8193-499d-8e1b-8cb5d3577499',
#        '897027c5-2dc2-4cef-b2cb-6aeeb6543508',
#        '0ddad543-d65d-4e5c-ac85-d7e7942f54af',
#        'EAA900C3-4DC6-4D18-9FCC-FE27B1DC3FD6',
#        '64C23924-0FA7-485A-B281-E3A3958E9A0B',
#        '67af84ec-ef7f-4599-b4bc-e8fec631b7b5',
#        '46ddad0d-411e-4bcf-ba26-ef68ca5f1ee4',
#        'cf6c02fa-acd8-4344-b279-c2d571b2519a',
#        '3627aa59-556b-4576-8f68-c0a1d0c8ddcc',
#        'd4c9d9ef-0239-471d-a91c-a5cedc1d7873',
#        '55f7cb6c-12ff-4e1a-8b52-ae600bc69a2d',
#        '0E4AE1B1-CA92-484B-969A-3010A04EBB05',
#        '95b37014-9369-45d6-aacc-c9639c964f87',
#        '23221cbc-682c-48b9-9f98-79a578208f30',
#        '22d468d9-8260-4efa-b5a9-c475a349bb63',
#        'f3197245-e1e1-432e-a2b7-2234a319e91a',
#        '7acc2e5f-bd96-45b4-911d-8d13689b9c8c',
#        '95B18569-D5D0-481E-8766-01CFF6543F40',
#        '2D63D59D-C196-4B36-A6EC-891F02BD28B8',
#        '74FF0CE6-15DA-4004-871E-787B13475F5D'], dtype=object)

# %%
assessmentUser = df[(df['event']=='assessment')&(df.userid == 'b9226e9d-f839-46e9-8e2b-e27fa42736aa')]['data']

# %%
assessmentUser.apply(getScore)
# Out:
# createdat
# 2019-12-05 12:00:00+00:00    18
# 2019-11-20 15:00:00+00:00    30
# 2019-11-27 21:00:00+00:00    29
# Name: data, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(assessmentUser.apply(getScore).sort_index())

# %% [markdown]
# ## New array with the scores of all users

# %%
userids = df.userid.unique()
scores = []
for i in range(len(userids)):
    x = df[(df['event']=='assessment')&(df.userid == userids[i])]['data']
    scores.append([userids[i],(x.apply(getScore).sort_index(0))])

# %%
dfScores = pd.DataFrame(scores, columns=['userid', 'score'])

# %%
scores
# Out:
# [['A01CFEC1-B0EA-4866-8739-940D6A507080',
#   Series([], Name: data, dtype: object)],
#  ['c57c753487db7965', Series([], Name: data, dtype: object)],
#  ['8041B5EB-7984-4CB9-9A58-4EFDC84F265D',
#   Series([], Name: data, dtype: object)],
#  ['46dc9b12-42c4-4ba7-8c1c-9d1404e0903a',
#   createdat
#   2019-12-18 17:00:00+00:00    20
#   2019-12-30 13:00:00+00:00    20
#   2020-01-10 03:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['812c2e41c64d3b51', Series([], Name: data, dtype: object)],
#  ['64bfce03-6337-4208-a1ac-d92269faf24b',
#   createdat
#   2019-11-26 17:00:00+00:00    23
#   2019-12-05 17:00:00+00:00    29
#   2019-12-20 08:00:00+00:00    18
#   2019-12-29 16:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['70a94f23afa7b234', Series([], Name: data, dtype: object)],
#  ['', Series([], Name: data, dtype: object)],
#  ['a03308ca-fbaf-4265-8257-b6ecf7ec4d40',
#   createdat
#   2020-02-17 13:00:00+00:00    11
#   Name: data, dtype: int64],
#  ['4A34E0CE-3ECC-44C0-8739-0E079A259A10',
#   Series([], Name: data, dtype: object)],
#  ['902FEAEE-E290-4424-BA44-04F70A77DC9D',
#   Series([], Name: data, dtype: object)],
#  ['E2D7D48D-08C5-4228-B9D6-7A9830FCBB48',
#   Series([], Name: data, dtype: object)],
#  ['38512D7C-8F81-4AD3-B7B9-46963C0635FC',
#   Series([], Name: data, dtype: object)],
#  ['c65dcc742f28bd0f', Series([], Name: data, dtype: object)],
#  ['fc9c6a6e-d60a-4d5c-a6bf-0fc9f644b91b',
#   createdat
#   2019-12-02 13:00:00+00:00    28
#   2019-12-10 11:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['e422b492c35609ef', Series([], Name: data, dtype: object)],
#  ['6a252400-4aaf-46ab-aeb7-6788d4bb140f',
#   createdat
#   2019-11-26 15:00:00+00:00     9
#   2019-12-05 10:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['a9a1e3f5498c6aac', Series([], Name: data, dtype: object)],
#  ['34224694-17A3-4806-ACBF-AE598912E003',
#   Series([], Name: data, dtype: object)],
#  ['9130c977-71cd-4b6e-a8e0-6d269e2e0022',
#   createdat
#   2019-11-18 09:00:00+00:00    20
#   2019-11-18 09:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['E9ACE06B-2605-4FAA-A6F0-C016743328FC',
#   Series([], Name: data, dtype: object)],
#  ['8F8A3E40-C1AF-4D0C-8456-72153A451747',
#   Series([], Name: data, dtype: object)],
#  ['c481f6cb3a459905', Series([], Name: data, dtype: object)],
#  ['422656486535f884', Series([], Name: data, dtype: object)],
#  ['ba7c625f-8845-492b-ad84-0e396fd26d5a',
#   Series([], Name: data, dtype: object)],
#  ['6359B6AD-DBA0-4DCF-8166-BB8ABACDC814',
#   Series([], Name: data, dtype: object)],
#  ['84AC2979-EF1E-4C68-ACD1-0AEB5AEF7200',
#   Series([], Name: data, dtype: object)],
#  ['fde78b86-e4f9-4546-853b-6882c8b4f085',
#   createdat
#   2019-12-02 19:00:00+00:00    11
#   2019-12-09 17:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['dc744407-3f77-4398-95a1-101c1e46eb7b',
#   createdat
#   2019-11-26 13:00:00+00:00    11
#   2019-12-17 08:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['9F69CC76-F402-476A-BB44-A84292010E46',
#   Series([], Name: data, dtype: object)],
#  ['7ccaf221-811f-4f97-be46-e5e01454e500',
#   createdat
#   2019-11-26 12:00:00+00:00    26
#   2019-12-06 10:00:00+00:00    27
#   Name: data, dtype: int64],
#  ['E0EF0138-AEB8-4F06-B0B4-7CE655B0DC52',
#   Series([], Name: data, dtype: object)],
#  ['2397e1e3-e7b4-459a-82c6-c8a69cdc7031',
#   createdat
#   2019-12-02 20:00:00+00:00    21
#   2019-12-09 17:00:00+00:00    22
#   2019-12-19 06:00:00+00:00    21
#   2019-12-28 22:00:00+00:00    16
#   2020-01-11 16:00:00+00:00    24
#   2020-01-26 12:00:00+00:00    21
#   2020-02-14 16:00:00+00:00    32
#   2020-02-23 20:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['E0861AD8-B39B-40BE-8C88-543DD2E5878F',
#   Series([], Name: data, dtype: object)],
#  ['bbe616de-e329-4acb-988f-b8180a109d88',
#   createdat
#   2019-12-02 22:00:00+00:00    22
#   2019-12-09 21:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['5730a6dc-4b30-48dc-b334-e8228a243c76',
#   createdat
#   2019-12-09 08:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['B8F2BB36-BDBB-4610-8B45-0717E7505C72',
#   Series([], Name: data, dtype: object)],
#  ['A586B11B-09C7-4212-A0B2-68ABA386375B',
#   Series([], Name: data, dtype: object)],
#  ['63947F2F-168F-48CB-A5EB-71A40A0FAC05',
#   Series([], Name: data, dtype: object)],
#  ['6f10800d4bc7a5f9', Series([], Name: data, dtype: object)],
#  ['b9226e9d-f839-46e9-8e2b-e27fa42736aa',
#   createdat
#   2019-11-20 15:00:00+00:00    30
#   2019-11-27 21:00:00+00:00    29
#   2019-12-05 12:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['1843b45d-4580-4969-bf0a-318a3bce4b32',
#   createdat
#   2019-11-21 18:00:00+00:00    26
#   2019-11-26 16:00:00+00:00    14
#   2019-11-28 07:00:00+00:00    15
#   2019-12-12 07:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['546b160edc74ce94', Series([], Name: data, dtype: object)],
#  ['696e2ae2-c892-4f43-aa0c-8336bd353d45',
#   createdat
#   2020-01-07 13:00:00+00:00    15
#   2020-01-28 22:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['9c9a096268a053b1', Series([], Name: data, dtype: object)],
#  ['0E596382-CBC5-4336-8A54-B10C04483D30',
#   Series([], Name: data, dtype: object)],
#  ['60CB3387-2B79-4949-AC18-964E8ED56D58',
#   Series([], Name: data, dtype: object)],
#  ['f8c2b15d-b803-435d-adf9-42ee09da9165',
#   createdat
#   2019-12-02 20:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['23ECCD1E-081C-465F-A868-2876DDA2C99E',
#   Series([], Name: data, dtype: object)],
#  ['F6681229-293C-4D2A-B8FA-A08CC0DEC710',
#   Series([], Name: data, dtype: object)],
#  ['54d3e190-ee81-4801-8b35-b484123f0080',
#   createdat
#   2020-01-07 19:00:00+00:00    11
#   2020-02-03 13:00:00+00:00    18
#   2020-02-19 16:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['2666fe4da6917afa', Series([], Name: data, dtype: object)],
#  ['1C3127FC-DFE6-4E44-9D5D-823E234078ED',
#   Series([], Name: data, dtype: object)],
#  ['6e30e339-2e5d-496b-9c33-7ceaad26c66e',
#   Series([], Name: data, dtype: object)],
#  ['d4db310c-c9c6-4d91-a116-9e004fb670be',
#   Series([], Name: data, dtype: object)],
#  ['aca95b64-daaf-494c-8178-d9acf60573d2',
#   Series([], Name: data, dtype: object)],
#  ['57d18538-07e7-4067-abcc-806f3d20654b',
#   Series([], Name: data, dtype: object)],
#  ['5BFB4CBA-F9F1-402D-AA8E-BDB788E1C264',
#   Series([], Name: data, dtype: object)],
#  ['3ADA6F03-837F-499F-8A1E-B2FE66BD9B3D',
#   Series([], Name: data, dtype: object)],
#  ['10568754-EDC4-482B-BADB-8D04F3AF1D66',
#   Series([], Name: data, dtype: object)],
#  ['42F56FE6-1C07-42D7-861D-108BFFDAB807',
#   Series([], Name: data, dtype: object)],
#  ['798790c2-c8b1-468d-b061-5ede38be36bc',
#   createdat
#   2020-02-13 12:00:00+00:00    12
#   2020-02-24 16:00:00+00:00    23
#   2020-02-25 13:00:00+00:00     6
#   Name: data, dtype: int64],
#  ['db49e66f-16c1-4940-922e-0f7504716642',
#   createdat
#   2020-02-15 11:00:00+00:00    28
#   Name: data, dtype: int64],
#  ['7562edab-708a-44b7-a78d-43d04c0579ea',
#   createdat
#   2020-02-15 18:00:00+00:00    21
#   2020-02-24 07:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['967ebdad-0c6e-40f7-8363-2fedf955c8cb',
#   createdat
#   2020-02-12 07:00:00+00:00    24
#   2020-02-23 07:00:00+00:00    21
#   2020-03-02 21:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['418cdc61-3e99-464d-8098-8dc0e48ac70d',
#   createdat
#   2020-02-13 14:00:00+00:00     9
#   2020-02-20 19:00:00+00:00    10
#   2020-02-25 17:00:00+00:00     5
#   Name: data, dtype: int64],
#  ['161B330F-59D7-4A7C-85DB-325721119AD5',
#   Series([], Name: data, dtype: object)],
#  ['c7d94497-16a6-4983-bbd8-d49e5939c3b4',
#   createdat
#   2019-11-20 17:00:00+00:00    25
#   2019-11-27 21:00:00+00:00    22
#   2019-12-04 20:00:00+00:00    19
#   2019-12-17 20:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['2777CD3D-7AA8-4461-BB54-DC7338E51EC1',
#   Series([], Name: data, dtype: object)],
#  ['8e8e3863-041e-497a-8544-107efdb3d5cb',
#   createdat
#   2020-01-08 09:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['1ACC78BD-B3AA-468F-ADA5-93D0D2F49023',
#   Series([], Name: data, dtype: object)],
#  ['512f8c5d-fd9b-41bc-a25b-f2f714316405',
#   createdat
#   2020-02-13 21:00:00+00:00    18
#   2020-02-21 15:00:00+00:00    20
#   2020-02-21 15:00:00+00:00    20
#   2020-02-29 08:00:00+00:00    13
#   Name: data, dtype: int64],
#  ['f5ff9aca-0969-432b-994f-e3ef1649ad04',
#   createdat
#   2020-02-13 21:00:00+00:00    21
#   2020-02-22 21:00:00+00:00    24
#   2020-02-24 23:00:00+00:00    15
#   2020-03-02 17:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['25dc8ef7-88f9-4cb8-809d-5eaa8e9557ca',
#   createdat
#   2020-02-13 12:00:00+00:00    17
#   2020-02-21 17:00:00+00:00    20
#   2020-02-28 12:00:00+00:00    13
#   Name: data, dtype: int64],
#  ['13e85eda-d37a-4ee1-b6e9-132136e184a7',
#   createdat
#   2020-02-11 13:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['02de1825-88b8-4bd7-a473-49620e9a7e60',
#   createdat
#   2020-02-11 13:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['2fd9db56-0177-4033-9ced-cb323a4cac68',
#   createdat
#   2020-02-11 13:00:00+00:00    16
#   2020-02-17 11:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['8510bafc-eb6d-42bb-a378-17077a0eaf9d',
#   createdat
#   2020-02-11 13:00:00+00:00    9
#   Name: data, dtype: int64],
#  ['2e348405-1f0e-45ee-8ab4-504ed346c305',
#   createdat
#   2020-02-11 13:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['c144e79d-43ec-4574-b878-43a1b52d383d',
#   createdat
#   2020-02-11 13:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['a6a9b40e-58a7-41ad-9c0b-9a225b7aa589',
#   createdat
#   2020-02-11 13:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['34ee15cb-9ba7-46a8-9370-495467e48381',
#   createdat
#   2020-02-11 14:00:00+00:00    17
#   2020-02-21 07:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['df17bd69-9d0f-4469-bbc5-22f43ddbfc03',
#   createdat
#   2019-11-26 17:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['B1200A69-9349-4BBA-B1FE-6EE602819C19',
#   Series([], Name: data, dtype: object)],
#  ['4FF4A0D8-3684-4502-844D-9810D5230982',
#   Series([], Name: data, dtype: object)],
#  ['42735b08-ef07-42c6-aa3c-34044f8635ac',
#   createdat
#   2020-02-14 12:00:00+00:00    23
#   2020-02-23 14:00:00+00:00    22
#   2020-02-28 14:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['f14deb82-408e-4c19-9628-c1599867f62f',
#   createdat
#   2020-02-13 20:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['f7b04a7c-d5dd-4472-bde0-af491d886cf3',
#   createdat
#   2020-02-13 15:00:00+00:00    20
#   2020-02-20 21:00:00+00:00    12
#   2020-02-25 20:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['36980a9e-ddfe-4bd4-953d-9de4d700a824',
#   createdat
#   2020-02-13 13:00:00+00:00    16
#   2020-02-20 13:00:00+00:00    24
#   2020-02-25 13:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['07B2B14E-7728-4DB8-8BEC-EC03B0B013DB',
#   Series([], Name: data, dtype: object)],
#  ['e2b25de5-444e-4f7c-82f2-a2207181a93a',
#   createdat
#   2019-11-15 13:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['8754B240-FC52-43ED-AA5B-90F4FC3861AF',
#   Series([], Name: data, dtype: object)],
#  ['41b2ab47f20c0028', Series([], Name: data, dtype: object)],
#  ['061f2a442a4fcf66', Series([], Name: data, dtype: object)],
#  ['da1eacad1374f44e', Series([], Name: data, dtype: object)],
#  ['cff4db93305c89de', Series([], Name: data, dtype: object)],
#  ['2251df37935a0656', Series([], Name: data, dtype: object)],
#  ['24AC0515-1DDB-409B-A8B0-64F16A0A816A',
#   Series([], Name: data, dtype: object)],
#  ['ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6',
#   createdat
#   2020-02-13 12:00:00+00:00    13
#   2020-02-20 22:00:00+00:00    13
#   2020-02-25 22:00:00+00:00     7
#   Name: data, dtype: int64],
#  ['18800e51-91be-403e-8c43-1743dee944c3',
#   createdat
#   2020-02-13 21:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['4e672aa1-7d57-48cb-8765-2e703c7944e6',
#   createdat
#   2019-12-03 01:00:00+00:00    25
#   2019-12-09 12:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['37BDED79-0AD7-4270-9459-85183B1CC53A',
#   Series([], Name: data, dtype: object)],
#  ['fd0bc52e-d1a4-405a-bd01-300a3d430209',
#   createdat
#   2019-11-29 08:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['ca68e1cd0f40585f', Series([], Name: data, dtype: object)],
#  ['B95D3D48-9F29-4699-9BBD-162D89CDC722',
#   Series([], Name: data, dtype: object)],
#  ['2be3847e-32d4-469e-a5a2-66c3840a4717',
#   createdat
#   2019-12-02 16:00:00+00:00    21
#   2019-12-09 16:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['90955803-F632-4ECB-87EF-4F7960F5740E',
#   Series([], Name: data, dtype: object)],
#  ['89d48011430dab6b', Series([], Name: data, dtype: object)],
#  ['127f8f12-4868-4991-b1f4-d951e8997638',
#   createdat
#   2020-02-13 16:00:00+00:00    9
#   2020-02-22 20:00:00+00:00    8
#   2020-02-29 09:00:00+00:00    6
#   Name: data, dtype: int64],
#  ['6dce0158-0d78-43a3-afdf-c6a5801859c7',
#   createdat
#   2020-02-13 12:00:00+00:00    24
#   2020-02-20 12:00:00+00:00    15
#   2020-02-25 10:00:00+00:00    29
#   2020-02-25 10:00:00+00:00    29
#   Name: data, dtype: int64],
#  ['485e779e-6d30-4184-8cb3-59445975e2a5',
#   createdat
#   2020-02-13 17:00:00+00:00    14
#   2020-03-01 21:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['8cef69d0-ed99-4bc2-b91e-ad18583a3754',
#   createdat
#   2020-03-01 14:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['91bcf5c1-ceaa-42de-abdc-c5632115f7a7',
#   createdat
#   2019-11-20 18:00:00+00:00    27
#   2019-11-27 21:00:00+00:00    22
#   2019-12-04 18:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['4c0831d9-6ad4-4cef-be58-3a510a6b602c',
#   createdat
#   2019-11-26 14:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['89406779-94FE-4E47-B6A0-08C60C16584B',
#   Series([], Name: data, dtype: object)],
#  ['062D2763-2D7B-487B-83F9-EE4E9E1A18FA',
#   Series([], Name: data, dtype: object)],
#  ['b3540d53-9891-4b14-b430-659d0a25ad5e',
#   createdat
#   2019-11-22 10:00:00+00:00    28
#   2019-11-27 12:00:00+00:00    12
#   2019-12-04 23:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['04f287a8-c498-4655-896b-0231185e16a8',
#   createdat
#   2020-02-14 09:00:00+00:00    24
#   2020-02-14 18:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['41e1dcca-20c7-4027-b36b-4386740a535b',
#   createdat
#   2020-02-13 18:00:00+00:00    18
#   2020-02-20 20:00:00+00:00    11
#   2020-02-25 21:00:00+00:00     8
#   Name: data, dtype: int64],
#  ['c2c76c5b-4b23-4371-b0dc-f37586b73665',
#   Series([], Name: data, dtype: object)],
#  ['F66D48B7-019E-46E8-9EAC-6B039E39C3FF',
#   Series([], Name: data, dtype: object)],
#  ['804092dc0980c958', Series([], Name: data, dtype: object)],
#  ['fd34dca14dae2587', Series([], Name: data, dtype: object)],
#  ['1787692d-11e7-443a-9c63-302fb9c7e4c7',
#   createdat
#   2020-02-13 15:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-02-24 17:00:00+00:00    17
#   2020-03-01 14:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['6a757a26-10f3-4dd8-a6ca-a2e9c7318128',
#   createdat
#   2020-02-06 12:00:00+00:00    6
#   2020-02-24 20:00:00+00:00    1
#   Name: data, dtype: int64],
#  ['2fe1a68c-620b-4a5e-a1ab-ef13866843ce',
#   Series([], Name: data, dtype: object)],
#  ['1b97b8c2-c0c2-4a8e-8770-f8fae46a3a3e',
#   Series([], Name: data, dtype: object)],
#  ['758794A6-BAEC-4247-8499-FE2B018B6523',
#   Series([], Name: data, dtype: object)],
#  ['00da7219-c1bd-4b67-acc5-fa6da0668d05',
#   createdat
#   2019-12-03 06:00:00+00:00    20
#   2019-12-10 06:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['d2348342b5c7ef36', Series([], Name: data, dtype: object)],
#  ['B554FD14-6625-4805-9CD5-5ED082C4E18B',
#   Series([], Name: data, dtype: object)],
#  ['811914dc-1c74-498c-9271-b8c0abb536b5',
#   createdat
#   2019-11-27 17:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['E17AB04B-A68F-4C08-B920-075A2FA824D5',
#   Series([], Name: data, dtype: object)],
#  ['09892EF9-FC34-44DE-88B8-58D627C6636E',
#   Series([], Name: data, dtype: object)],
#  ['c4fe084ac590838a', Series([], Name: data, dtype: object)],
#  ['20F9BD67-64C5-44AB-9EF5-8ED664514D0D',
#   Series([], Name: data, dtype: object)],
#  ['C1753934-9F85-448C-90D2-FC69F5EFC4DB',
#   Series([], Name: data, dtype: object)],
#  ['4884D316-2533-4BC0-A5AE-4C4A37405FB4',
#   Series([], Name: data, dtype: object)],
#  ['169E42E6-06C9-46ED-B45E-21C88B1CADC1',
#   Series([], Name: data, dtype: object)],
#  ['05A7E3CF-613E-4272-8DAC-FA7B8FA2677E',
#   Series([], Name: data, dtype: object)],
#  ['0317E9ED-6A5B-4A33-827F-3A73485071E1',
#   Series([], Name: data, dtype: object)],
#  ['d428fa268048fa93', Series([], Name: data, dtype: object)],
#  ['ed66ee43-8077-49ac-a03f-4be17c94eb17',
#   createdat
#   2020-01-27 11:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['6347d70b7d291f95', Series([], Name: data, dtype: object)],
#  ['1CED046F-257E-46FD-92FA-B46095BF33A6',
#   Series([], Name: data, dtype: object)],
#  ['837a5405f4ca726f', Series([], Name: data, dtype: object)],
#  ['b313ea43-b62a-4405-b32b-c809d08529a1',
#   createdat
#   2019-11-26 15:00:00+00:00    8
#   2019-12-02 20:00:00+00:00    8
#   Name: data, dtype: int64],
#  ['6A6006D4-682A-4352-BD83-D116007097E4',
#   Series([], Name: data, dtype: object)],
#  ['74da9410-d798-4442-9137-6be07825c023',
#   createdat
#   2019-12-02 18:00:00+00:00    22
#   2019-12-09 18:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['9259D142-4EF5-4FCE-B47D-4AB9226312EA',
#   Series([], Name: data, dtype: object)],
#  ['15b11623e50bf6d4', Series([], Name: data, dtype: object)],
#  ['2224f1f8a8f4e529', Series([], Name: data, dtype: object)],
#  ['9c47cf0b47d5c9c5', Series([], Name: data, dtype: object)],
#  ['8514d65d-b725-4f39-b1fc-5b0a614ff18a',
#   createdat
#   2020-02-11 14:00:00+00:00    31
#   2020-02-25 13:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['1ad71f48-c2cd-4261-97da-5ac6d513e8ee',
#   createdat
#   2020-02-11 13:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['98f3942d-c356-48c2-946e-02f91726e9b7',
#   createdat
#   2020-02-11 13:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['83b49381-564b-4772-a863-1730e70e571d',
#   createdat
#   2020-02-11 13:00:00+00:00    30
#   Name: data, dtype: int64],
#  ['58b8ef9c-79a8-453f-bc61-23ecfa013574',
#   createdat
#   2020-02-11 13:00:00+00:00    30
#   Name: data, dtype: int64],
#  ['bd477c25-b5e1-4ef5-8f9e-50f9579043d8',
#   createdat
#   2020-02-11 14:00:00+00:00    19
#   2020-02-22 19:00:00+00:00    21
#   2020-03-01 21:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['414c053e-a8a3-48fd-99b6-055a4b0cb39a',
#   createdat
#   2020-02-11 20:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['e4e586dc-1d64-49d2-823a-b7df2ad935d9',
#   createdat
#   2020-02-11 15:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['2566cff2-e8a3-4ee1-a1f9-d4a141b8dc90',
#   createdat
#   2020-02-11 15:00:00+00:00    28
#   Name: data, dtype: int64],
#  ['09d6008f-32cd-4cc0-ac2c-5f7d0c5d041f',
#   createdat
#   2020-02-19 10:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['cb5cbcae-8af9-4561-a0c9-1ce4908d59d1',
#   createdat
#   2020-02-11 14:00:00+00:00    18
#   2020-02-12 13:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['4a5a61c1-7b89-4a98-8c02-b2322afbd821',
#   createdat
#   2020-02-14 13:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['ec0dd93f-fa73-4262-af5c-fb508e87b6e1',
#   Series([], Name: data, dtype: object)],
#  ['c11178dd-cee1-4431-99ef-db8f02d1f6d7',
#   createdat
#   2020-02-12 16:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['62ec9abb-9f9c-49c6-8feb-a9485cbbc7ab',
#   createdat
#   2020-02-13 15:00:00+00:00    19
#   2020-02-20 21:00:00+00:00    14
#   2020-02-27 08:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['044a1e47-e2aa-4d90-8ad3-00c63096d085',
#   createdat
#   2020-02-11 17:00:00+00:00    13
#   Name: data, dtype: int64],
#  ['e48cdd0765262bbc', Series([], Name: data, dtype: object)],
#  ['832a9d1a-cfce-4799-9665-df83b0068ee2',
#   createdat
#   2020-02-10 09:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['7c2c5111-fe6b-4fa3-8ac2-704156d31ac2',
#   createdat
#   2020-02-10 12:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['44c3e3e5-5fdf-438b-b59a-aaba9d73ced6',
#   createdat
#   2020-02-10 15:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['d235664b-1334-4f72-8ba7-9b3a735d2f3d',
#   Series([], Name: data, dtype: object)],
#  ['9768a63d-772a-4c85-b902-d4d2152b6f17',
#   createdat
#   2020-02-12 14:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['9156d626-59cb-4a58-919a-b0824cfcd8ed',
#   Series([], Name: data, dtype: object)],
#  ['d9816d3a-14aa-472b-a7dd-2ffaec421a3e',
#   createdat
#   2020-02-10 15:00:00+00:00    13
#   2020-02-25 09:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['e359dc7c-4190-4f23-838d-ae420718645b',
#   createdat
#   2020-02-27 16:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['42d1d0c5-53e6-4c3e-b947-9f62ce6b95ab',
#   createdat
#   2020-02-18 12:00:00+00:00    11
#   Name: data, dtype: int64],
#  ['3016f096-50d6-4613-ac4e-ebd984abcdaf',
#   createdat
#   2020-02-14 12:00:00+00:00    28
#   2020-02-20 17:00:00+00:00    18
#   2020-02-25 19:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['6f467272-a48b-4118-b3f0-a0838b653c17',
#   createdat
#   2020-02-11 10:00:00+00:00    13
#   2020-02-27 09:00:00+00:00    13
#   Name: data, dtype: int64],
#  ['327396da-73c8-4cb0-8334-77a2f472b2e0',
#   createdat
#   2020-02-13 22:00:00+00:00    10
#   Name: data, dtype: int64],
#  ['98602C5C-3793-4FB6-8C4B-36795624FFE5',
#   Series([], Name: data, dtype: object)],
#  ['38bd9767f1b6486a', Series([], Name: data, dtype: object)],
#  ['14c04a584fda0d70', Series([], Name: data, dtype: object)],
#  ['dc9578be-0093-4526-8495-ea3550933fb1',
#   createdat
#   2020-02-12 07:00:00+00:00    8
#   Name: data, dtype: int64],
#  ['d0c3d07a-bc7f-4f43-b49d-058f1dd20517',
#   createdat
#   2020-02-11 21:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['6d7d417e-bff2-4bbd-8703-2dc1d9a33ace',
#   createdat
#   2020-02-17 11:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['30e9490b-003b-4c94-9473-1b6229e238c5',
#   createdat
#   2020-02-11 14:00:00+00:00    20
#   2020-02-25 13:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['e6a76d13-dce5-47e2-8210-34f7b2b1abb6',
#   createdat
#   2020-02-15 09:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['f26b45f7-1b81-4d9c-8e14-b900bea9e2fd',
#   createdat
#   2020-02-11 13:00:00+00:00    22
#   2020-03-02 15:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['a30c0386-233f-4cab-805d-4f0de6a4630e',
#   createdat
#   2020-02-13 18:00:00+00:00    19
#   2020-03-02 21:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['758277e0-a73b-4e3a-9368-928d61ea407b',
#   Series([], Name: data, dtype: object)],
#  ['42A5A385-8FDA-4903-9520-02F4684D33C1',
#   Series([], Name: data, dtype: object)],
#  ['9D3CE609-4DCC-4425-A70F-D1011297B0EF',
#   Series([], Name: data, dtype: object)],
#  ['cbc76578-b3af-407e-b1b1-656eb08a9c7e',
#   createdat
#   2020-02-12 12:00:00+00:00    27
#   Name: data, dtype: int64],
#  ['21218fbe-4ef4-48c4-a6cc-fec0a9705243',
#   createdat
#   2020-02-11 15:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['b0acecbf-6aac-4df4-bda6-6b2d5234193d',
#   createdat
#   2019-11-20 15:00:00+00:00    18
#   2019-11-23 12:00:00+00:00    13
#   2019-11-27 10:00:00+00:00    14
#   2019-12-02 12:00:00+00:00    17
#   2019-12-04 23:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['c137634b-03c7-439c-b504-6dbe2374c4e9',
#   createdat
#   2019-11-20 11:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['6F380742-C788-42F7-9A56-090BF2B76E0F',
#   Series([], Name: data, dtype: object)],
#  ['6eedcfe1-ab68-4fb3-b858-a1190da5816f',
#   Series([], Name: data, dtype: object)],
#  ['3376fe04-5281-4c85-b4e6-7e8cd88970cb',
#   createdat
#   2020-02-16 21:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['6bf74034-746b-40a9-b32c-ff56dc082683',
#   createdat
#   2019-11-21 06:00:00+00:00    26
#   2019-11-28 07:00:00+00:00    28
#   2019-12-05 01:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['A264F912-2BDA-4311-833E-FC4E207DE7C7',
#   Series([], Name: data, dtype: object)],
#  ['a7bf7453-a776-4e35-ac5d-a766a36b98d2',
#   createdat
#   2020-02-11 17:00:00+00:00    34
#   Name: data, dtype: int64],
#  ['e41090ce-d241-45f9-ac28-d8baba77fc91',
#   createdat
#   2019-11-21 15:00:00+00:00    23
#   2019-11-27 17:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['0ac87483-0b76-46c6-823d-51280084f7e0',
#   createdat
#   2019-11-20 15:00:00+00:00    26
#   2019-12-04 19:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['43CEEA10-0F45-4E67-9BD7-5D88783BBB05',
#   Series([], Name: data, dtype: object)],
#  ['e62dedad-169c-4d5d-a883-0951d8f3500c',
#   createdat
#   2020-02-13 17:00:00+00:00    19
#   2020-02-21 22:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['417ec70a-ec44-4ef4-88d0-a3a03cda5131',
#   createdat
#   2020-02-13 11:00:00+00:00    19
#   2020-02-20 23:00:00+00:00    14
#   2020-02-26 00:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['851ad004-0956-482c-b024-db4479b8946b',
#   createdat
#   2020-02-11 17:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['340de9e9-9957-4ae6-b6ee-d7fa51959ea4',
#   createdat
#   2020-02-11 13:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['6aa95895-5274-4770-ab38-0a1beeef1681',
#   createdat
#   2020-02-17 11:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['1a8b8e72-4a68-4cc2-ad11-882143b68619',
#   createdat
#   2020-02-11 13:00:00+00:00    10
#   Name: data, dtype: int64],
#  ['c02e93b1-2371-4139-bd4e-372edc53b62d',
#   createdat
#   2020-02-13 20:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['01021dae-990a-4713-b087-a4208dde3f3d',
#   createdat
#   2020-02-20 11:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['f69d743e-7f09-4a13-bfa6-f37b7a330b46',
#   createdat
#   2020-02-20 09:00:00+00:00    28
#   Name: data, dtype: int64],
#  ['2D99E723-AEA0-4FBA-9574-A0E9112785B3',
#   Series([], Name: data, dtype: object)],
#  ['3d359af5-f066-4ac2-9a9f-d93f3cea0011',
#   createdat
#   2019-11-21 20:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['059f7353-1c2d-4a75-a1d5-9a4ca5251794',
#   createdat
#   2020-02-11 16:00:00+00:00    11
#   Name: data, dtype: int64],
#  ['56369fa6-0850-4112-a1f6-cb430a0af776',
#   createdat
#   2020-02-21 11:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['7E0B0934-DB48-429C-9AC2-3ED58117514C',
#   Series([], Name: data, dtype: object)],
#  ['8ca7d00e-c062-425a-9b26-2105e874b8d9',
#   createdat
#   2019-11-26 12:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['3167EF50-1132-4574-9F8A-E202D3EF16BA',
#   Series([], Name: data, dtype: object)],
#  ['a08bd409-62ce-4b62-b24c-463c9f1c20ba',
#   createdat
#   2020-02-13 15:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['f21a3d0f-c97d-4805-95c0-f588f1b1f04e',
#   createdat
#   2020-02-13 14:00:00+00:00    9
#   Name: data, dtype: int64],
#  ['efe7db4f-e32b-48ca-99cc-d341f4cf201e',
#   createdat
#   2020-02-13 15:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['3133a51a-1751-4df8-a3bd-1df4f31d0263',
#   createdat
#   2020-02-11 13:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['f54a26ca-9476-4514-b46b-fd155c253f39',
#   createdat
#   2020-02-11 13:00:00+00:00    11
#   Name: data, dtype: int64],
#  ['7431f66a-4856-4174-8b51-b73b5bf5f88a',
#   createdat
#   2020-02-11 13:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['aa55c25e-505d-4e85-b642-65ecb4249b3b',
#   Series([], Name: data, dtype: object)],
#  ['A8227FB6-6D7A-43F1-BE70-827B74C6D4C7',
#   Series([], Name: data, dtype: object)],
#  ['5769A367-B76B-4EA7-822B-332D1499F3E5',
#   Series([], Name: data, dtype: object)],
#  ['2dc654e4-1adc-4125-84a5-078578ecb315',
#   createdat
#   2020-02-13 17:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['53801b9e-49b5-4b08-b964-4adfa1f965b2',
#   createdat
#   2020-02-17 19:00:00+00:00    12
#   Name: data, dtype: int64],
#  ['264BB644-1957-4A04-9ECF-00A2893766A1',
#   Series([], Name: data, dtype: object)],
#  ['c15a74f8-debf-4efc-8cbe-618634c05c57',
#   Series([], Name: data, dtype: object)],
#  ['70241aa9-2dbe-4722-a8f0-d29cac38855e',
#   createdat
#   2020-02-11 16:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['3f972c43a988e728', Series([], Name: data, dtype: object)],
#  ['ed9e1e97-6eee-430e-bfb1-916e8a91354e',
#   createdat
#   2020-02-18 13:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['d621e6004268731e', Series([], Name: data, dtype: object)],
#  ['47006b43-c4d6-4b13-b836-4a8f91103650',
#   createdat
#   2020-02-11 14:00:00+00:00    18
#   Name: data, dtype: int64],
#  ['daee3887-b466-4baf-9f67-666f375d26af',
#   createdat
#   2019-11-26 14:00:00+00:00    10
#   Name: data, dtype: int64],
#  ['AC44D941-1CC2-4E13-A624-01957477C7E3',
#   Series([], Name: data, dtype: object)],
#  ['9b3c9e70-17a9-4245-ba75-c890daa333d4',
#   createdat
#   2020-02-17 10:00:00+00:00    25
#   Name: data, dtype: int64],
#  ['33dfe98b-5cdb-4133-a20c-08e02683d117',
#   createdat
#   2020-02-19 14:00:00+00:00    26
#   2020-02-27 16:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['3d803fe7-a4c9-4e39-be43-5c7d7d46d117',
#   Series([], Name: data, dtype: object)],
#  ['fd82739a-393f-4a3e-ada8-4f2355154c77',
#   createdat
#   2020-02-05 19:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['FC12B169-0ADF-457E-BF24-7BD17BA01857',
#   Series([], Name: data, dtype: object)],
#  ['7b1a5a5d-aca3-4709-9880-76b38a57edf3',
#   createdat
#   2020-02-17 10:00:00+00:00    18
#   2020-02-27 19:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['29920e58-3a00-4e00-b7f1-94b3522a462e',
#   createdat
#   2020-02-11 13:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['46a93fab-1e49-46d9-8faa-c21fb0a78ecd',
#   createdat
#   2020-02-13 18:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['d16520f6-ac2f-44fd-94b1-cf7f62eda852',
#   createdat
#   2020-02-14 10:00:00+00:00    29
#   Name: data, dtype: int64],
#  ['0b24938d-75ef-438b-a1f4-60e227c44601',
#   createdat
#   2020-02-13 18:00:00+00:00    27
#   Name: data, dtype: int64],
#  ['4104a431-13ce-4e9d-abd9-9de4ca8788a8',
#   createdat
#   2020-02-17 16:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['c4618b6d-6a80-4ac8-8382-45efb12e698f',
#   Series([], Name: data, dtype: object)],
#  ['fd6b7f72-4220-4e08-a230-94c6cbe2fe0d',
#   createdat
#   2020-02-12 07:00:00+00:00    40
#   Name: data, dtype: int64],
#  ['21bc1db2-4384-4d9d-ba29-fa06b194fc30',
#   createdat
#   2020-02-13 17:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['3a7bcedd-a613-4b51-aca0-3208bea934cc',
#   createdat
#   2020-02-13 10:00:00+00:00    38
#   Name: data, dtype: int64],
#  ['14b74364-ce50-45ca-8c29-3de397c804a3',
#   createdat
#   2020-02-24 16:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['176AA6F1-C2CF-4EEA-8C46-E220C3F268F7',
#   Series([], Name: data, dtype: object)],
#  ['3C71B67D-8FAC-4F3E-A25F-E47750201BE7',
#   Series([], Name: data, dtype: object)],
#  ['fa598088-7914-4bee-b615-b4ef529c18d2',
#   createdat
#   2020-02-12 11:00:00+00:00    16
#   Name: data, dtype: int64],
#  ['8c1cc8b1-0656-4837-816b-effa50d61338',
#   createdat
#   2020-02-25 12:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['4D8AA9FB-EB69-47A1-8230-A0AAA9424767',
#   Series([], Name: data, dtype: object)],
#  ['F05CABA5-969B-4C04-B81A-2AC54AE23C11',
#   Series([], Name: data, dtype: object)],
#  ['9c2bd9b2-7cb6-419c-8024-5b872a039f46',
#   createdat
#   2020-02-11 14:00:00+00:00    16
#   2020-02-11 18:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['88391e33-7932-4fb4-9a7f-8d51279f5d3e',
#   createdat
#   2020-02-11 22:00:00+00:00    13
#   Name: data, dtype: int64],
#  ['cf6b1eea-eb1e-453d-84da-9dfcba375511',
#   createdat
#   2020-02-12 22:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['2199482A-8705-49B6-B09D-2FCC728B7BB1',
#   Series([], Name: data, dtype: object)],
#  ['49256c1f-05ae-4d5e-888f-4395c49c7db1',
#   createdat
#   2020-02-20 16:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['9bf79edb-d59c-4100-a162-0fd9a4d3f2a9',
#   createdat
#   2020-02-19 16:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['0bb0a670-1f15-42b5-9be5-e0a8cfd9759a',
#   Series([], Name: data, dtype: object)],
#  ['e3a037bf-4cee-4a31-b82d-20a82f732d3b',
#   createdat
#   2020-02-20 16:00:00+00:00    3
#   Name: data, dtype: int64],
#  ['BC032968-78E3-4277-9842-C0D2BD0FF215',
#   Series([], Name: data, dtype: object)],
#  ['6698006d-ecce-4731-862d-410295f43fe7',
#   Series([], Name: data, dtype: object)],
#  ['325da042-721e-4733-86e5-cf45fbe01c45',
#   createdat
#   2020-02-18 10:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['e8d5e264-1013-408a-a4c9-068b3d79858e',
#   createdat
#   2020-02-13 17:00:00+00:00    17
#   Name: data, dtype: int64],
#  ['ca44748a-c8e2-4b2a-8de1-e73c0e9636b3',
#   createdat
#   2020-02-13 17:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['4fc9b53f698c0bf4', Series([], Name: data, dtype: object)],
#  ['A6945F8A-DD8C-49C9-9FCB-2DD773249714',
#   Series([], Name: data, dtype: object)],
#  ['39b877b7-3146-44ec-b413-20999d75b874',
#   createdat
#   2020-02-11 14:00:00+00:00    19
#   Name: data, dtype: int64],
#  ['6529fdf3-9886-41e8-a15f-264332e51ac6',
#   createdat
#   2020-02-11 17:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['bf95c98d-4e90-4d13-8df5-286f6622a181',
#   Series([], Name: data, dtype: object)],
#  ['ba0f4912-ab8d-483c-8a7a-d3cab06cfd3f',
#   createdat
#   2020-02-22 06:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['339ae7ff-b5c5-4ebc-9caa-1d247e8e58e0',
#   createdat
#   2020-02-18 09:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['e253249b-66c1-4fff-87d1-3adbe827b3fc',
#   createdat
#   2020-02-13 14:00:00+00:00    20
#   Name: data, dtype: int64],
#  ['9623721b-49b1-49ba-ae0b-7645c72f1888',
#   createdat
#   2020-02-17 16:00:00+00:00    10
#   Name: data, dtype: int64],
#  ['7d6fc309-19d9-4740-96e9-bbbf3184588e',
#   createdat
#   2020-02-19 10:00:00+00:00    26
#   Name: data, dtype: int64],
#  ['d7844a2d-8249-408a-ac75-820d308f0c9a',
#   Series([], Name: data, dtype: object)],
#  ['2c4d55f3-1058-446d-b83b-a1ebc71b6f1e',
#   createdat
#   2020-02-11 16:00:00+00:00    22
#   Name: data, dtype: int64],
#  ['0110e85c-8193-499d-8e1b-8cb5d3577499',
#   Series([], Name: data, dtype: object)],
#  ['897027c5-2dc2-4cef-b2cb-6aeeb6543508',
#   createdat
#   2020-02-18 09:00:00+00:00    14
#   Name: data, dtype: int64],
#  ['0ddad543-d65d-4e5c-ac85-d7e7942f54af',
#   Series([], Name: data, dtype: object)],
#  ['EAA900C3-4DC6-4D18-9FCC-FE27B1DC3FD6',
#   Series([], Name: data, dtype: object)],
#  ['64C23924-0FA7-485A-B281-E3A3958E9A0B',
#   Series([], Name: data, dtype: object)],
#  ['67af84ec-ef7f-4599-b4bc-e8fec631b7b5',
#   Series([], Name: data, dtype: object)],
#  ['46ddad0d-411e-4bcf-ba26-ef68ca5f1ee4',
#   Series([], Name: data, dtype: object)],
#  ['cf6c02fa-acd8-4344-b279-c2d571b2519a',
#   createdat
#   2020-02-19 10:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['3627aa59-556b-4576-8f68-c0a1d0c8ddcc',
#   Series([], Name: data, dtype: object)],
#  ['d4c9d9ef-0239-471d-a91c-a5cedc1d7873',
#   createdat
#   2020-02-20 13:00:00+00:00    21
#   Name: data, dtype: int64],
#  ['55f7cb6c-12ff-4e1a-8b52-ae600bc69a2d',
#   Series([], Name: data, dtype: object)],
#  ['0E4AE1B1-CA92-484B-969A-3010A04EBB05',
#   Series([], Name: data, dtype: object)],
#  ['95b37014-9369-45d6-aacc-c9639c964f87',
#   createdat
#   2020-02-19 11:00:00+00:00    24
#   Name: data, dtype: int64],
#  ['23221cbc-682c-48b9-9f98-79a578208f30',
#   Series([], Name: data, dtype: object)],
#  ['22d468d9-8260-4efa-b5a9-c475a349bb63',
#   createdat
#   2020-02-13 21:00:00+00:00    23
#   Name: data, dtype: int64],
#  ['f3197245-e1e1-432e-a2b7-2234a319e91a',
#   Series([], Name: data, dtype: object)],
#  ['7acc2e5f-bd96-45b4-911d-8d13689b9c8c',
#   createdat
#   2020-02-13 20:00:00+00:00    15
#   Name: data, dtype: int64],
#  ['95B18569-D5D0-481E-8766-01CFF6543F40',
#   Series([], Name: data, dtype: object)],
#  ['2D63D59D-C196-4B36-A6EC-891F02BD28B8',
#   Series([], Name: data, dtype: object)],
#  ['74FF0CE6-15DA-4004-871E-787B13475F5D',
#   Series([], Name: data, dtype: object)]]

# %%
plt.plot(scores[2][1])

# %%
df[(df['event']=='impression')]['data'][3]
# Out:
# '{view=null, question=null, answers=null, score=null, programme-id=null, programme-title=null, activity-id=250d838a-54c3-4aae-bf6f-5a6057890aa1, activity-title=Deep belly breathing, slide=1, page=null, input-id=null, feedback=null, audio-id=null, duration=null, position=null, level=null, module-id=null, module-title=null, action=null, labels=null, labels-selected=null, records-done=null, questionsanswered=null, notification=null, date=null, programme-state=null, step=null, suggested=null, programme-step=null, answer-id=null, aswer-value=null, answer-ids=null, answer-values=null, example=null, numofdaysago=null, iscompleted=null, group=null}'

# %%
a = df[(df['event']=='media_pause')&(df.userid == 'b9226e9d-f839-46e9-8e2b-e27fa42736aa')]['data'][0].split(",")

# %%
df.view
# Out:
# createdat
# 2019-11-16 08:00:00+00:00        None
# 2019-11-16 08:00:00+00:00        None
# 2019-11-16 08:00:00+00:00      splash
# 2019-11-16 08:00:00+00:00      splash
# 2019-11-16 08:00:00+00:00      splash
#                                ...
# 2019-11-27 16:00:00+00:00        home
# 2019-11-27 00:00:00+00:00        home
# 2019-11-27 00:00:00+00:00        home
# 2019-11-27 09:00:00+00:00    activity
# 2019-11-27 09:00:00+00:00    activity
# Name: view, Length: 81616, dtype: object

# %%
host_sum_df =(df
               .groupby('event')
               .count()
               .sort_values(by='unique_name',ascending=False))

host_sum_df
# Out:
#                               deploymentenv  device  product  schema  source  \
# event
# screen_view                           26507   26507    26507   26507   26507
# tap                                   24061   24061    24061   24061   24061
# impression                            13441   13441    13441   13441   13441
# app_pause                              4446    4446     4446    4446    4446
# app_resume                             2953    2953     2953    2953    2953
# app_open                               1784    1784     1784    1784    1784
# media_finish                            868     868      868     868     868
# activity_results                        413     413      413     413     413
# media_play                              288     288      288     288     288
# assessment                              280     280      280     280     280
# media_pause                             170     170      170     170     170
# select_date                              88      88       88      88      88
# app_resume_from_notification             79      79       79      79      79
# app_open_from_notification               44      44       44      44      44
# media_restart                            39      39       39      39      39
#
#                                type  unique_name   user  userid   view   data  \
# event
# screen_view                   26507        26507  26507   26507  26507   8988
# tap                           24061        24061  24061   24061  24061  18677
# impression                    13441        13441  13441   13441  13441  12588
# app_pause                      4446         4446   4446    4446   4394      0
# app_resume                     2953         2953   2953    2953   2827      0
# app_open                       1784         1784   1784    1784      0      0
# media_finish                    868          868    868     868    868    868
# activity_results                413          413    413     413    413    413
# media_play                      288          288    288     288    288    288
# assessment                      280          280    280     280    280    280
# media_pause                     170          170    170     170    170    170
# select_date                      88           88     88      88     88     88
# app_resume_from_notification     79           79     79      79     23     79
# app_open_from_notification       44           44     44      44      1     44
# media_restart                    39           39     39      39     39     39
#
#                               element  error  level  message  stacktrace  \
# event
# screen_view                      1365      0      0        0           0
# tap                             24061      0      0        0           0
# impression                       9601      0      0        0           0
# app_pause                           0      0      0        0           0
# app_resume                          0      0      0        0           0
# app_open                            0      0      0        0           0
# media_finish                      868      0      0        0           0
# activity_results                    0      0      0        0           0
# media_play                        288      0      0        0           0
# assessment                          0      0      0        0           0
# media_pause                       170      0      0        0           0
# select_date                         0      0      0        0           0
# app_resume_from_notification        0      0      0        0           0
# app_open_from_notification          0      0      0        0           0
# media_restart                      39      0      0        0           0
#
#                                year  month    day  week_start
# event
# screen_view                   26507  26507  26507       26507
# tap                           24061  24061  24061       24061
# impression                    13441  13441  13441       13441
# app_pause                      4446   4446   4446        4446
# app_resume                     2953   2953   2953        2953
# app_open                       1784   1784   1784        1784
# media_finish                    868    868    868         868
# activity_results                413    413    413         413
# media_play                      288    288    288         288
# assessment                      280    280    280         280
# media_pause                     170    170    170         170
# select_date                      88     88     88          88
# app_resume_from_notification     79     79     79          79
# app_open_from_notification       44     44     44          44
# media_restart                    39     39     39          39

# %%
df['hour'] = df.index.hour

# %%
df['hour']
# Out:
# createdat
# 2019-11-16 08:00:00+00:00     8
# 2019-11-16 08:00:00+00:00     8
# 2019-11-16 08:00:00+00:00     8
# 2019-11-16 08:00:00+00:00     8
# 2019-11-16 08:00:00+00:00     8
#                              ..
# 2019-11-27 16:00:00+00:00    16
# 2019-11-27 00:00:00+00:00     0
# 2019-11-27 00:00:00+00:00     0
# 2019-11-27 09:00:00+00:00     9
# 2019-11-27 09:00:00+00:00     9
# Name: hour, Length: 81616, dtype: int64

# %% [markdown]
# ## Events during the day

# %%
x = df[(df['event']=='assessment')]['data']
x = x.apply(getScore)

# %%
x = df.copy()
x =(df
        .groupby('hour')
        .count()
        .sort_values(by='hour',ascending=True))

# %%
x
# Out:
#       deploymentenv  device  event  product  schema  source  type  \
# hour
# 0              2503    2503   1784     2503    2503    2503  1784
# 1               736     736    706      736     736     736   706
# 2               135     135    135      135     135     135   135
# 3               139     139    119      139     139     139   119
# 4               170     170    170      170     170     170   170
# 5               232     232    232      232     232     232   232
# 6              1412    1412   1305     1412    1412    1412  1305
# 7              1875    1875   1872     1875    1875    1875  1872
# 8              2632    2632   2617     2632    2632    2632  2617
# 9              4298    4298   3960     4298    4298    4298  3960
# 10             2646    2646   2428     2646    2646    2646  2428
# 11             3325    3325   3310     3325    3325    3325  3310
# 12             3967    3967   3783     3967    3967    3967  3783
# 13             6279    6279   5952     6279    6279    6279  5952
# 14             3403    3403   3392     3403    3403    3403  3392
# 15             6131    6131   5007     6131    6131    6131  5007
# 16             5897    5897   5497     5897    5897    5897  5497
# 17             4584    4584   4415     4584    4584    4584  4415
# 18             3795    3795   3525     3795    3795    3795  3525
# 19             5520    5520   4878     5520    5520    5520  4878
# 20             7209    7209   6765     7209    7209    7209  6765
# 21             6477    6477   5682     6477    6477    6477  5682
# 22             5914    5914   5605     5914    5914    5914  5605
# 23             2337    2337   2322     2337    2337    2337  2322
#
#       unique_name  user  userid  ...  data  element  error  level  message  \
# hour                             ...
# 0            1784  2503    2503  ...   966      816    719    719      719
# 1             706   736     736  ...   435      340     30     30       30
# 2             135   135     135  ...    45       54      0      0        0
# 3             119   139     139  ...    64       46     20     20       20
# 4             170   170     170  ...    97       80      0      0        0
# 5             232   232     232  ...    96       97      0      0        0
# 6            1305  1412    1412  ...   573      515    107    107      107
# 7            1872  1875    1875  ...  1106      879      3      3        3
# 8            2617  2632    2632  ...  1344     1276     15     15       15
# 9            3960  4298    4298  ...  2259     1872    338    338      338
# 10           2428  2646    2646  ...  1295     1084    218    218      218
# 11           3310  3325    3325  ...  1828     1618     15     15       15
# 12           3783  3967    3967  ...  2002     1667    184    184      184
# 13           5952  6279    6279  ...  3134     2742    327    327      327
# 14           3392  3403    3403  ...  1870     1609     11     11       11
# 15           5007  6131    6131  ...  2950     2600   1124   1124     1124
# 16           5497  5897    5897  ...  3208     2730    400    400      400
# 17           4415  4584    4584  ...  2335     2000    169    169      169
# 18           3525  3795    3795  ...  1930     1659    270    270      270
# 19           4878  5520    5520  ...  2837     2304    642    642      642
# 20           6765  7209    7209  ...  4025     3267    444    444      444
# 21           5682  6477    6477  ...  3304     2844    795    795      795
# 22           5605  5914    5914  ...  3467     3070    309    309      309
# 23           2322  2337    2337  ...  1352     1223     15     15       15
#
#       stacktrace  year  month   day  week_start
# hour
# 0            719  2503   2503  2503        2503
# 1             30   736    736   736         736
# 2              0   135    135   135         135
# 3             20   139    139   139         139
# 4              0   170    170   170         170
# 5              0   232    232   232         232
# 6            107  1412   1412  1412        1412
# 7              3  1875   1875  1875        1875
# 8             15  2632   2632  2632        2632
# 9            338  4298   4298  4298        4298
# 10           218  2646   2646  2646        2646
# 11            15  3325   3325  3325        3325
# 12           184  3967   3967  3967        3967
# 13           327  6279   6279  6279        6279
# 14            11  3403   3403  3403        3403
# 15          1124  6131   6131  6131        6131
# 16           400  5897   5897  5897        5897
# 17           169  4584   4584  4584        4584
# 18           270  3795   3795  3795        3795
# 19           642  5520   5520  5520        5520
# 20           444  7209   7209  7209        7209
# 21           795  6477   6477  6477        6477
# 22           309  5914   5914  5914        5914
# 23            15  2337   2337  2337        2337
#
# [24 rows x 21 columns]

# %%
plt.plot(x['event'])

# %%
plt.plot(x['userid'])

# %%
def outputPerUser(df, cat):
    df.dropna(subset = [cat], inplace=True)
    
    df.sort_values(["userid", cat])
    valid_ids = df['userid'].unique()
    new = df[(df['userid'].isin(valid_ids))]
    new = new.groupby('userid')
    new = new[cat].agg(list)
    new = new.to_frame()[cat]
    newdf = new.to_frame()   
    return newdf

# %%
x = df.copy()
x = outputPerUser(x, 'hour')

# %%
x
# Out:
#                                                                                    hour
# userid
#                                       [8, 8, 8, 8, 8, 8, 16, 16, 16, 16, 16, 16, 16,...
# 00da7219-c1bd-4b67-acc5-fa6da0668d05  [21, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,...
# 01021dae-990a-4713-b087-a4208dde3f3d  [11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 1...
# 0110e85c-8193-499d-8e1b-8cb5d3577499           [10, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# 02de1825-88b8-4bd7-a473-49620e9a7e60  [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 1...
# ...                                                                                 ...
# fd0bc52e-d1a4-405a-bd01-300a3d430209  [8, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, ...
# fd34dca14dae2587                      [10, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 1...
# fd6b7f72-4220-4e08-a230-94c6cbe2fe0d  [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# fd82739a-393f-4a3e-ada8-4f2355154c77  [19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 1...
# fde78b86-e4f9-4546-853b-6882c8b4f085  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, ...
#
# [311 rows x 1 columns]

# %%
x = [x['hour'][0]]
plt.hist(x, bins = 5)
plt.show()

# %%
weekdf = df.copy()
weekdf.groupby(['week_start', 'userid']).nunique()
# Out:
#                                                  deploymentenv  device  event  \
# week_start userid
# 2019-11-11 061f2a442a4fcf66                                  1       1      3
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB              1       1      4
#            2251df37935a0656                                  1       1      3
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A              1       1      3
#            41b2ab47f20c0028                                  1       1      3
# ...                                                        ...     ...    ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b              1       5      4
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6              1       3      5
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e              1       1      4
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd              1       1      5
#            f5ff9aca-0969-432b-994f-e3ef1649ad04              1       1      7
#
#                                                  product  schema  source  \
# week_start userid
# 2019-11-11 061f2a442a4fcf66                            1       1       1
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB        1       1       1
#            2251df37935a0656                            1       1       1
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A        1       1       1
#            41b2ab47f20c0028                            1       1       1
# ...                                                  ...     ...     ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b        1       2       2
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6        1       1       1
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e        1       1       1
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd        1       1       1
#            f5ff9aca-0969-432b-994f-e3ef1649ad04        1       1       1
#
#                                                  type  unique_name  user  \
# week_start userid
# 2019-11-11 061f2a442a4fcf66                         1            4     1
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB     1           10     1
#            2251df37935a0656                         1            5     1
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A     1            3     1
#            41b2ab47f20c0028                         1            4     1
# ...                                               ...          ...   ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b     1           28     1
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6     1           36     1
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e     1            7     1
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd     1           30     1
#            f5ff9aca-0969-432b-994f-e3ef1649ad04     1           60     1
#
#                                                  userid  ...  element  error  \
# week_start userid                                        ...
# 2019-11-11 061f2a442a4fcf66                           1  ...        1      0
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB       1  ...        4      0
#            2251df37935a0656                           1  ...        2      0
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A       1  ...        0      0
#            41b2ab47f20c0028                           1  ...        1      0
# ...                                                 ...  ...      ...    ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b       1  ...       14      1
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6       1  ...       17      0
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e       1  ...        2      0
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd       1  ...       14      0
#            f5ff9aca-0969-432b-994f-e3ef1649ad04       1  ...       26      0
#
#                                                  level  message  stacktrace  \
# week_start userid
# 2019-11-11 061f2a442a4fcf66                          0        0           0
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB      0        0           0
#            2251df37935a0656                          0        0           0
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A      0        0           0
#            41b2ab47f20c0028                          0        0           0
# ...                                                ...      ...         ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b      1        1           1
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6      0        0           0
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e      0        0           0
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd      0        0           0
#            f5ff9aca-0969-432b-994f-e3ef1649ad04      0        0           0
#
#                                                  year  month  day  week_start  \
# week_start userid
# 2019-11-11 061f2a442a4fcf66                         1      1    1           1
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB     1      1    1           1
#            2251df37935a0656                         1      1    1           1
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A     1      1    1           1
#            41b2ab47f20c0028                         1      1    1           1
# ...                                               ...    ...  ...         ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b     1      1    1           1
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6     1      1    1           1
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e     1      1    1           1
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd     1      1    1           1
#            f5ff9aca-0969-432b-994f-e3ef1649ad04     1      1    1           1
#
#                                                  hour
# week_start userid
# 2019-11-11 061f2a442a4fcf66                         1
#            07B2B14E-7728-4DB8-8BEC-EC03B0B013DB     1
#            2251df37935a0656                         1
#            24AC0515-1DDB-409B-A8B0-64F16A0A816A     1
#            41b2ab47f20c0028                         1
# ...                                               ...
# 2020-03-02 aa55c25e-505d-4e85-b642-65ecb4249b3b     4
#            ac8f82d9-f1a1-44ce-8f7d-04672fbef7f6     3
#            ed9e1e97-6eee-430e-bfb1-916e8a91354e     1
#            f26b45f7-1b81-4d9c-8e14-b900bea9e2fd     1
#            f5ff9aca-0969-432b-994f-e3ef1649ad04     1
#
# [685 rows x 22 columns]
